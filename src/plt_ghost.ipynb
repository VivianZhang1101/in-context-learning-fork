# %%
from collections import OrderedDict
import re
import os

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import torch
from tqdm.notebook import tqdm
import numpy as np
import matplotlib
from eval import get_run_metrics, read_run_dir, get_model_from_run
from plot_utils import basic_plot, collect_results, relevant_model_names

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

sns.set_theme('notebook', 'darkgrid')
palette = sns.color_palette('colorblind')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
with open('./data/loss_list.txt', 'r') as file:
    loss_list = [float(line.strip()) for line in file]
with open('./data/loss_list_2.txt', 'r') as file:
    loss_list_2 = [float(line.strip()) for line in file]

# %%
prompt_length = 76
matplotlib.rcParams['text.usetex'] = True
plt.figure(figsize=(10, 5), facecolor='none')
plt.plot(range(1, prompt_length), loss_list[:prompt_length], linewidth=2)
plt.plot(range(1, prompt_length), loss_list_2[:prompt_length], linewidth=2)

x = [1, 25, 50, 75]
plt.xticks(x)
plt.yscale('log')
# plt.axvline(x=50, color='grey', linestyle='--')  # Grey vertical line
# plt.legend()
plt.xlabel('In-context Examples', fontsize = 20)
plt.ylabel('Mean Squared Error',fontsize = 20)
plt.grid(color='lightgray', linestyle='-', linewidth=0.5)
plt.savefig("../output/ghost.pdf", bbox_inches = "tight", transparent=True)
plt.show()

# %%
average = sum(loss_list[:prompt_length]) / len(loss_list[:prompt_length])
average
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 average = sum(loss_list[:prompt_length]) / len(loss_list[:prompt_length])
#       2 average
#
# NameError: name 'prompt_length' is not defined
